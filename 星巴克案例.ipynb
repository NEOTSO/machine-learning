# %% [markdown]
# # 星巴克案例

# %%
import pandas as pd

# %%
data = pd.read_csv('./data/starbucks/directory.csv')

# %%
data.head()
# Out:
#        Brand  Store Number        Store Name Ownership Type  \
# 0  Starbucks  47370-257954     Meritxell, 96       Licensed
# 1  Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2  Starbucks  47089-256771         Dana Mall       Licensed
# 3  Starbucks  22126-218024        Twofour 54       Licensed
# 4  Starbucks  17127-178586      Al Ain Tower       Licensed
#
#                     Street Address              City State/Province Country  \
# 0                Av. Meritxell, 96  Andorra la Vella              7      AD
# 1             1 Street 69, Al Jarf             Ajman             AJ      AE
# 2     Sheikh Khalifa Bin Zayed St.             Ajman             AJ      AE
# 3                  Al Salam Street         Abu Dhabi             AZ      AE
# 4  Khaldiya Area, Abu Dhabi Island         Abu Dhabi             AZ      AE
#
#   Postcode Phone Number                 Timezone  Longitude  Latitude
# 0    AD500    376818720  GMT+1:00 Europe/Andorra       1.53     42.51
# ...

# %%
g1 = data.groupby(['Country']).count()

# %%
g1
# Out:
#          Brand  Store Number  Store Name  Ownership Type  Street Address  \
# Country
# AD           1             1           1               1               1
# AE         144           144         144             144             144
# AR         108           108         108             108             108
# AT          18            18          18              18              18
# AU          22            22          22              22              22
# ...        ...           ...         ...             ...             ...
# TT           3             3           3               3               3
# TW         394           394         394             394             394
# US       13608         13608       13608           13608           13608
# VN          25            25          25              25              25
# ZA           3             3           3               3               3
#
#           City  State/Province  Postcode  Phone Number  Timezone  Longitude  \
# ...

# %%
g1['Brand'].plot(kind='bar', figsize=(20, 8))

# %%
data.groupby(['Country', 'State/Province']).count()
# Out:
#                         Brand  Store Number  Store Name  Ownership Type  \
# Country State/Province
# AD      7                   1             1           1               1
# AE      AJ                  2             2           2               2
#         AZ                 48            48          48              48
#         DU                 82            82          82              82
#         FU                  2             2           2               2
# ...                       ...           ...         ...             ...
# US      WV                 25            25          25              25
#         WY                 23            23          23              23
# VN      HN                  6             6           6               6
#         SG                 19            19          19              19
# ZA      GT                  3             3           3               3
#
#                         Street Address  City  Postcode  Phone Number  \
# ...
